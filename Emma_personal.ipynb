# %%
import numpy as np
import pandas as pd
import Basic_functions as bf

from sklearn.preprocessing import StandardScaler, RobustScaler
import lightgbm as lgbm

# %%
data = bf.read_files("Speeches")

# %%
data = np.array(data)
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# %%
data[:,0].std()
# Out:
# np.float64(0.010007113604198285)

# %%
data_scaled[:,0].std()
# Out:
# np.float64(1.0000000000000004)

# %%
params = {
    "objective": "multiclass",
    "num_class": 3,
    "metric": "multi_logloss",
    "boosting_type": "gbdt",
    "num_leaves": 31,
    "learning_rate": 0.05,
    "feature_fraction": 0.9,
    "bagging_fraction": 0.8,
    "bagging_freq": 5,
    "verbose": -1
}

# %%
test = open("Speeches\A._Bartholdy_Møllers_prædiken_1._søndag_efter_paske.txt", "r", encoding="utf-8").read().strip()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\jonas\AppData\Local\Temp\ipykernel_15500\3273076216.py:1: SyntaxWarning: invalid escape sequence '\A'
#   test = open("Speeches\A._Bartholdy_Møllers_prædiken_1._søndag_efter_paske.txt", "r", encoding="utf-8").read().strip()

# %%
np.where(test == "a")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 np.where(test == "a")
#
# ValueError: Calling nonzero on 0d arrays is not allowed. Use np.atleast_1d(scalar).nonzero() instead. If the context of this error is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.

# %%
"a" in test
# Out:
# True

# %%
test.find("\n")
# Out:
# 58

# %%
idxs = np.array([i for i, ch in enumerate(test) if ch == "\n"])

# %%
idxs
# Out:
# array([  58,   75,  117,  167,  204,  224,  271,  272,  273,  419,  997,
#        1400, 1771, 2388, 2964, 3249, 3812, 4102, 4544, 4990, 5200, 5317])
