# %%
import numpy as np
import matplotlib.pyplot as plt
import Basic_functions as bf
from scipy.sparse import vstack


import torch as pt
import optuna as opt
import sklearn.metrics as skm
import sklearn.utils as sku
from sklearn.preprocessing import StandardScaler

# %%
import torch.nn as nn
from torch.nn import CrossEntropyLoss
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchao.sparsity.training import(
    SemiSparseLinear,
    SemiSparseActivationLinear,
    swap_linear_with_semi_sparse_linear,
    swap_semi_sparse_linear_with_linear,
)
#from torch.nn import L1Loss
#from scipy.special import expit
# Out:
# W0527 12:05:14.123000 39160 site-packages/torch/distributed/elastic/multiprocessing/redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.

# %%
trigrams = np.genfromtxt('txt_files/trigons_filtered.txt', delimiter='\n', dtype=str,encoding='cp1252')
data_speeches, labels_speeches = bf.read_files('Speeches', trigrams, sparse=True)
data_articles, labels_articles = bf.read_files('articles_old', trigrams, sparse=True)

# %%
data_comb = vstack([data_speeches, data_articles], format='csr')
labels_comb = np.concatenate([labels_speeches, labels_articles])
labels_SvsA = np.concatenate([np.ones(len(labels_speeches)), np.zeros(len(labels_articles))])

# %%
data_comb, labels_comb = sku.shuffle(data_comb, labels_SvsA, random_state=42)

# %%
data_train, data_train_labels, data_val, data_val_labels, data_test, data_test_labels = bf.train_val_test_split(data_comb, labels_comb, val_size=0.20, test_size=0.05)

# %%
data_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 26405091 stored elements and shape (27170, 5606)>

# %%
class MyDataset(Dataset):    
    def __init__(self, X_data, y_data):
        self.input = X_data
        self.truth = y_data
        
    def __getitem__(self, index):
        return self.input[index], self.truth[index]
        
    def __len__ (self):
        return self.truth.shape[0]

#In pytorch, there is an additional step of turning your data into tensors
train_data = MyDataset(data_train, data_train_labels)
val_data = MyDataset(data_val, data_val_labels)
test_data = MyDataset(data_test, data_test_labels)

# %%
# Define the model:
class TestModel(nn.Module):
    def __init__(self):
        super(TestModel, self).__init__()        # Here we define the layers.
        self.input_layer = nn.Linear(len(trigrams), 192)     #In pytorch, you define the input and output edges.
        self.hidden_layer1 = nn.Linear(192, 48)
        self.hidden_layer2 = nn.Linear(48, 12)
        self.output_layer = nn.Linear(12, 2)
        self.relu = nn.ReLU()
        
    def forward(self, inputs):                  # Here we define how data passes through the layers. 
        x = self.input_layer(inputs)            # Also here, pytorch is a bit more explicit in defining the layers and activation function separately
        x = self.relu(x)
        x = self.hidden_layer1(x)
        x = self.relu(x)
        x = self.hidden_layer2(x)
        x = self.relu(x)
        x = self.output_layer(x)
        return x

# %%
# Training loop:
def Train(model, optimizer, loss_function, train_loader, validation_loader, device, epochs):
    validation_loss = []
    training_loss   = []
    model.train()
    for e in range(0, epochs):
        epoch_loss = 0
        n_minibatches = 0
        for input_train_batch, truth_train_batch in train_loader:
            input_train_batch, truth_train_batch = input_train_batch.to(device), truth_train_batch.to(device)
            optimizer.zero_grad()
            prediction = model(input_train_batch)  # This asks our model to produce predictions on the training batch            
            loss = loss_function(prediction, truth_train_batch.long())  # This calculates the loss
            loss.backward()                                             # This initiates the backpropagation
            optimizer.step()
            epoch_loss += loss.item()
            n_minibatches += 1
        
        # Now that the model have trained 1 epoch, we evaluate the model on the validation set:
        valid_loss = Validate(model, validation_loader, device, loss_function)
        validation_loss.append(valid_loss)
        training_loss.append(epoch_loss/n_minibatches)
        print('EPOCH: %s | training loss: %s  | validation loss: %s'%(e+1,round(epoch_loss/n_minibatches,3), round(valid_loss, 3)))
    return training_loss, validation_loss


def Validate(model, validation_loader, device, loss_function):
    model.eval()
    n_batches  = 0
    validation_loss = 0
    with pt.no_grad():
        for input_valid_batch, truth_valid_batch in validation_loader:
            input_valid_batch, truth_valid_batch = input_valid_batch.to(device), truth_valid_batch.to(device)
            prediction = model(input_valid_batch)
            loss = loss_function(prediction, truth_valid_batch.long())
            validation_loss += loss.item()
            n_batches += 1
    validation_loss = validation_loss/n_batches
    return validation_loss


def Predict(model, prediction_loader, device):
    model.eval()
    predictions = []
    print('PREDICTING!')
    with pt.no_grad():
        for input_pred_batch, _ in prediction_loader:
            input_pred_batch = input_pred_batch.to(device)
            prediction = model(input_pred_batch)
            predictions.extend(prediction.numpy())
    print('Done Predicting!')
    return predictions
                
class MeanRelativeAbsoluteDeviationLoss(nn.Module):
    def __init__(self, eps=1e-8):
        super().__init__()
        self.eps = eps
                
    def forward(self, prediction, target):
        prediction = prediction.view_as(target)
        relative_absolute_error = pt.abs(prediction - target) / (pt.abs(target) + self.eps)
        return pt.mean(relative_absolute_error)

# %%
def sparse_collate(batch):
    xs, ys = zip(*batch)

    first = xs[0]
    n_features = first.shape[-1]

    batch_rows = []
    batch_cols = []
    batch_vals = []

    for i, x in enumerate(xs):
        x = x.tocoo()
        batch_rows.append(np.full_like(x.col, i, dtype=np.int64))
        batch_cols.append(x.col.astype(np.int64))
        batch_vals.append(x.data.astype(np.float32))

    indices = pt.tensor(
        np.vstack([np.concatenate(batch_rows), np.concatenate(batch_cols)]),
        dtype=pt.long
    )
    values = pt.tensor(np.concatenate(batch_vals), dtype=pt.float32)

    X = pt.sparse_coo_tensor(indices, values, size=(len(xs), n_features)).coalesce()
    y = pt.tensor(np.asarray(ys), dtype=pt.long)
    return X, y

# %%
# Now everything is ready, and we thus define the optimisation (hyper-) parameters:
learning_rate = 1e-3      # The step size in the direction of "good" from stocastic gradient descent (important!)
batch_size    = 32        # The size of the batches used for each of the stocastic gradient descent calculations
n_epochs      = 8        # Number of epochs, i.e. times that we run through the entire dataset

device = pt.device('cuda' if pt.cuda.is_available() else 'cpu')
model = TestModel() 
sparse_config = {
    "seq.0": SemiSparseLinear,
}
swap_linear_with_semi_sparse_linear(model, sparse_config)
model.to(device)       # Mount the model to the selected device. Either CPU or GPU.
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
loss_function = CrossEntropyLoss()
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True, collate_fn=sparse_collate)
validation_loader = DataLoader(dataset=val_data, batch_size=batch_size, collate_fn=sparse_collate)

training_loss, validation_loss = Train(model, optimizer, loss_function, train_loader, validation_loader, device, n_epochs)
# Out:
# /var/folders/rp/p2_g6d3j74ggpl15kr0_k5zc0000gn/T/ipykernel_39160/936182257.py:23: UserWarning: Sparse invariant checks are implicitly disabled. Memory errors (e.g. SEGFAULT) will occur when operating on a sparse tensor which violates the invariants, but checks incur performance overhead. To silence this warning, explicitly opt in or out. See `torch.sparse.check_sparse_tensor_invariants.__doc__` for guidance.  (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/Context.cpp:767.)
#   X = pt.sparse_coo_tensor(indices, values, size=(len(xs), n_features)).coalesce()
# EPOCH: 1 | training loss: 0.252  | validation loss: 0.056
# EPOCH: 2 | training loss: 0.048  | validation loss: 0.041
# EPOCH: 3 | training loss: 0.038  | validation loss: 0.038
# EPOCH: 4 | training loss: 0.033  | validation loss: 0.036
# EPOCH: 5 | training loss: 0.028  | validation loss: 0.034
# EPOCH: 6 | training loss: 0.026  | validation loss: 0.029
# EPOCH: 7 | training loss: 0.023  | validation loss: 0.029
# EPOCH: 8 | training loss: 0.021  | validation loss: 0.036

# %%
batch_size = 32
#prediction_loader = DataLoader(dataset=test_data, batch_size=batch_size, collate_fn=sparse_collate)
prediction_loader = DataLoader(dataset=val_data, batch_size=batch_size, collate_fn=sparse_collate)
predictions = Predict(model, prediction_loader, device)

predictions
# Out:
# PREDICTING!
# Done Predicting!
# [array([ 6.7184396, -7.1288543], dtype=float32),
#  array([ 5.2863164, -5.565408 ], dtype=float32),
#  array([ 8.3328  , -8.891411], dtype=float32),
#  array([ 5.4053154, -5.6953044], dtype=float32),
#  array([ 5.2835503, -5.5623407], dtype=float32),
#  array([ 6.938128, -7.368771], dtype=float32),
#  array([ 6.5423136, -6.9366956], dtype=float32),
#  array([ 7.4257445, -7.9011245], dtype=float32),
#  array([ 0.5331528 , -0.27781093], dtype=float32),
#  array([-2.5039456,  3.1483781], dtype=float32),
#  array([ 5.6082435, -5.9168344], dtype=float32),
#  array([ 6.5858636, -6.984172 ], dtype=float32),
#  array([ 8.132899, -8.673134], dtype=float32),
#  array([ 5.1698728, -5.438264 ], dtype=float32),
#  array([-2.5065715,  3.1514063], dtype=float32),
#  array([ 4.237059 , -4.4195967], dtype=float32),
#  array([ 4.7575355, -4.9880404], dtype=float32),
#  array([ 5.644844, -5.956796], dtype=float32),
#  array([ 7.131467 , -7.5798507], dtype=float32),
#  array([ 2.498669 , -2.4962547], dtype=float32),
#  array([ 6.834452, -7.255543], dtype=float32),
#  array([ 8.02238 , -8.552483], dtype=float32),
#  array([ 5.0111494, -5.2650332], dtype=float32),
#  array([ 6.0074034, -6.3526096], dtype=float32),
#  array([ 6.9070644, -7.334828 ], dtype=float32),
#  array([ 5.8778605, -6.211314 ], dtype=float32),
#  array([ 4.9903   , -5.2423496], dtype=float32),
#  array([ 5.648601 , -5.9609904], dtype=float32),
#  array([ 3.599887 , -3.7208645], dtype=float32),
#  array([ 6.8873396, -7.3133836], dtype=float32),
#  array([ 0.7656864, -0.5401505], dtype=float32),
#  array([-2.510342,  3.155785], dtype=float32),
#  array([ 5.9767165, -6.3191504], dtype=float32),
#  array([ 4.073613 , -4.2405925], dtype=float32),
#  array([ 5.0162277, -5.270554 ], dtype=float32),
#  array([ 5.9987793, -6.343192 ], dtype=float32),
#  array([ 1.1979611, -1.0258913], dtype=float32),
#  array([ 5.3830814, -5.6711245], dtype=float32),
#  array([ 2.6641848, -2.6840308], dtype=float32),
#  array([ 5.971848, -6.313827], dtype=float32),
#  array([ 6.6057634, -7.006001 ], dtype=float32),
#  array([ 5.559913, -5.864062], dtype=float32),
#  array([ 4.1266437, -4.298587 ], dtype=float32),
#  array([ 5.369551, -5.656342], dtype=float32),
#  array([ 5.9785056, -6.321119 ], dtype=float32),
#  array([ 5.9938493, -6.337824 ], dtype=float32),
#  array([-2.5283575,  3.176776 ], dtype=float32),
#  array([ 5.9411755, -6.28033  ], dtype=float32),
#  array([ 5.157301 , -5.4245396], dtype=float32),
#  array([ 5.5385423, -5.8408256], dtype=float32),
#  array([ 7.0946426, -7.539627 ], dtype=float32),
#  array([ 7.8219724, -8.33362  ], dtype=float32),
#  array([ 6.1347127, -6.4915905], dtype=float32),
#  array([ 5.985641, -6.328936], dtype=float32),
#  array([ 5.554687, -5.858391], dtype=float32),
#  array([-2.272188,  2.880004], dtype=float32),
#  array([ 5.1915636, -5.4620132], dtype=float32),
#  array([ 5.0058484, -5.2592497], dtype=float32),
#  array([-2.4541888,  3.0906577], dtype=float32),
#  array([ 5.0510726, -5.3085756], dtype=float32),
#  array([ 3.920609 , -4.0728927], dtype=float32),
#  array([ 4.324838, -4.515757], dtype=float32),
#  array([-1.7988605,  2.3341105], dtype=float32),
#  array([ 3.9355657, -4.0893292], dtype=float32),
#  array([ 5.7836556, -6.108409 ], dtype=float32),
#  array([ 4.6934075, -4.9181213], dtype=float32),
#  array([ 4.0443854, -4.2087193], dtype=float32),
#  array([ 3.3515162, -3.4472039], dtype=float32),
#  array([ 5.253641, -5.529737], dtype=float32),
#  array([ 2.9423854, -2.99624  ], dtype=float32),
#  array([ 4.6476216, -4.86813  ], dtype=float32),
#  array([ 5.3032017, -5.5838227], dtype=float32),
#  array([ 6.9000177, -7.327113 ], dtype=float32),
#  array([-2.523037,  3.170537], dtype=float32),
#  array([ 7.5861325, -8.076231 ], dtype=float32),
#  array([ 5.7315464, -6.05143  ], dtype=float32),
#  array([ 4.5152817, -4.723906 ], dtype=float32),
#  array([ 5.220562 , -5.4936223], dtype=float32),
#  array([ 3.8426259, -3.987238 ], dtype=float32),
#  array([ 3.9337244, -4.087209 ], dtype=float32),
#  array([ 3.6162152, -3.7388415], dtype=float32),
#  array([ 6.196789, -6.559352], dtype=float32),
#  array([ 3.8424356, -3.987079 ], dtype=float32),
#  array([-2.0679746,  2.6440663], dtype=float32),
#  array([ 3.3501015, -3.4455545], dtype=float32),
#  array([ 3.2893622, -3.3787405], dtype=float32),
#  array([ 6.8676558, -7.2917895], dtype=float32),
#  array([-2.4408872,  3.07535  ], dtype=float32),
#  array([ 5.256004, -5.532292], dtype=float32),
#  array([ 6.147955, -6.506082], dtype=float32),
#  array([ 4.8608713, -5.100986 ], dtype=float32),
#  array([ 4.31266  , -4.5024285], dtype=float32),
#  array([ 4.099569, -4.26902 ], dtype=float32),
#  array([ 4.4018846, -4.600356 ], dtype=float32),
#  array([ 6.198362 , -6.5611653], dtype=float32),
#  array([ 5.2179704, -5.4907665], dtype=float32),
#  array([ 5.4784718, -5.775179 ], dtype=float32),
#  array([ 4.9123693, -5.157162 ], dtype=float32),
#  array([ 5.868994 , -6.2015896], dtype=float32),
#  array([-2.5082662,  3.153428 ], dtype=float32),
#  array([ 2.8620908, -2.9075718], dtype=float32),
#  array([ 6.2035413, -6.56679  ], dtype=float32),
#  array([ 7.7518234, -8.25716  ], dtype=float32),
#  array([ 4.5250363, -4.7345033], dtype=float32),
#  array([ 5.2724433, -5.5502315], dtype=float32),
#  array([ 4.0860515, -4.2543116], dtype=float32),
#  array([ 3.4847908, -3.5938027], dtype=float32),
#  array([ 4.2507324, -4.4346843], dtype=float32),
#  array([ 4.992661, -5.244797], dtype=float32),
#  array([ 6.7679315, -7.182926 ], dtype=float32),
#  array([ 6.6456585, -7.0494957], dtype=float32),
#  array([ 5.231591, -5.505643], dtype=float32),
#  array([ 5.360411 , -5.6462855], dtype=float32),
#  array([ 6.030213 , -6.3775854], dtype=float32),
#  array([ 4.8847694, -5.1270084], dtype=float32),
#  array([ 5.109957 , -5.3728986], dtype=float32),
#  array([ 4.068239, -4.234711], dtype=float32),
#  array([ 5.471717 , -5.7678103], dtype=float32),
#  array([ 3.2218394, -3.3039641], dtype=float32),
#  array([ 8.27647 , -8.829909], dtype=float32),
#  array([ 5.1942797, -5.4649067], dtype=float32),
#  array([ 5.7148924, -6.0332685], dtype=float32),
#  array([ 5.1907697, -5.4610147], dtype=float32),
#  array([ 5.4659944, -5.7615757], dtype=float32),
#  array([ 4.3361554, -4.528226 ], dtype=float32),
#  array([ 5.8113556, -6.1386194], dtype=float32),
#  array([ 4.712757, -4.939215], dtype=float32),
#  array([ 4.508147, -4.716209], dtype=float32),
#  array([ 6.8226113, -7.242617 ], dtype=float32),
#  array([ 2.9933393, -3.0523143], dtype=float32),
#  array([-2.2651596,  2.8720152], dtype=float32),
#  array([ 5.3917384, -5.680556 ], dtype=float32),
#  array([ 4.2379885, -4.4207373], dtype=float32),
#  array([ 0.7550791, -0.5277697], dtype=float32),
#  array([ 3.6441956, -3.769895 ], dtype=float32),
#  array([ 4.094632, -4.263759], dtype=float32),
#  array([ 0.6930593 , -0.45790932], dtype=float32),
#  array([ 5.194472, -5.465104], dtype=float32),
#  array([-2.5070126,  3.1519508], dtype=float32),
#  array([ 4.1763153, -4.3533287], dtype=float32),
#  array([ 4.9314766, -5.1780276], dtype=float32),
#  array([ 6.7360106, -7.1480827], dtype=float32),
#  array([ 5.91678  , -6.2536693], dtype=float32),
#  array([-1.3666124,  1.8654898], dtype=float32),
#  array([ 6.090014, -6.442845], dtype=float32),
#  array([ 5.307682 , -5.5887384], dtype=float32),
#  array([ 3.708133 , -3.8400283], dtype=float32),
#  array([ 5.4789944, -5.7756925], dtype=float32),
#  array([ 5.8350267, -6.1644716], dtype=float32),
#  array([ 6.5534344, -6.9487453], dtype=float32),
#  array([ 4.9871335, -5.2388096], dtype=float32),
#  array([ 5.268767 , -5.5462484], dtype=float32),
#  array([ 5.185227 , -5.4550924], dtype=float32),
#  array([ 4.7354813, -4.9641037], dtype=float32),
#  array([ 5.7887216, -6.1139417], dtype=float32),
#  array([ 3.7885447, -3.9281075], dtype=float32),
#  array([ 5.5768023, -5.882557 ], dtype=float32),
#  array([ 5.391771, -5.680559], dtype=float32),
#  array([ 4.463403 , -4.6674495], dtype=float32),
#  array([ 6.7183185, -7.1287966], dtype=float32),
#  array([ 4.775617 , -5.0078206], dtype=float32),
#  array([ 5.1554155, -5.422483 ], dtype=float32),
#  array([ 5.3463974, -5.631041 ], dtype=float32),
#  array([ 3.2948267, -3.3846068], dtype=float32),
#  array([ 6.000434, -6.345021], dtype=float32),
#  array([ 7.6594267, -8.1562195], dtype=float32),
#  array([-2.5078816,  3.1529236], dtype=float32),
#  array([ 4.7314095, -4.959574 ], dtype=float32),
#  array([ 6.646105 , -7.0499744], dtype=float32),
#  array([-2.4829414,  3.12405  ], dtype=float32),
#  array([ 7.198176, -7.65263 ], dtype=float32),
#  array([-2.3131714,  2.927443 ], dtype=float32),
#  array([-2.5082273,  3.1533277], dtype=float32),
#  array([ 5.29229  , -5.5719647], dtype=float32),
#  array([ 7.2987537, -7.7624154], dtype=float32),
#  array([ 6.120715 , -6.4764013], dtype=float32),
#  array([ 3.5155416, -3.6279469], dtype=float32),
#  array([ 5.031786, -5.287504], dtype=float32),
#  array([ 4.639717, -4.859554], dtype=float32),
#  array([ 6.639865 , -7.0431404], dtype=float32),
#  array([ 6.3172746, -6.6909266], dtype=float32),
#  array([ 5.3502398, -5.635199 ], dtype=float32),
#  array([ 4.3435626, -4.5362644], dtype=float32),
#  array([ 5.356385 , -5.6418986], dtype=float32),
#  array([ 5.697794, -6.014614], dtype=float32),
#  array([ 3.529233 , -3.6428564], dtype=float32),
#  array([ 5.070082, -5.32933 ], dtype=float32),
#  array([ 4.912294 , -5.1570377], dtype=float32),
#  array([ 5.67515  , -5.9898505], dtype=float32),
#  array([ 4.176969 , -4.3539753], dtype=float32),
#  array([ 6.4543104, -6.840572 ], dtype=float32),
#  array([ 5.800188 , -6.1264586], dtype=float32),
#  array([ 5.9677715, -6.309478 ], dtype=float32),
#  array([ 4.9559646, -5.204784 ], dtype=float32),
#  array([ 2.056861 , -1.9932117], dtype=float32),
#  array([-2.4884806,  3.1304216], dtype=float32),
#  array([ 7.6486936, -8.144468 ], dtype=float32),
#  array([ 4.6390824, -4.858798 ], dtype=float32),
#  array([-0.0788134 ,  0.41330642], dtype=float32),
#  array([ 5.395821 , -5.6849194], dtype=float32),
#  array([ 6.5067296, -6.897857 ], dtype=float32),
#  array([ 4.9327664, -5.179489 ], dtype=float32),
#  array([ 6.1685834, -6.5286374], dtype=float32),
#  array([-1.4239769,  1.9303554], dtype=float32),
#  array([ 7.7405696, -8.24478  ], dtype=float32),
#  array([ 6.9566097, -7.3889556], dtype=float32),
#  array([ 4.380723 , -4.5772986], dtype=float32),
#  array([ 6.62546  , -7.0273905], dtype=float32),
#  array([ 6.992301 , -7.4278884], dtype=float32),
#  array([ 4.1388474, -4.312044 ], dtype=float32),
#  array([ 5.1393995, -5.4050307], dtype=float32),
#  array([ 5.413819, -5.704661], dtype=float32),
#  array([ 4.1495385, -4.323871 ], dtype=float32),
#  array([ 8.416861, -8.983363], dtype=float32),
#  array([-2.1663334,  2.757796 ], dtype=float32),
#  array([ 6.306463, -6.679094], dtype=float32),
#  array([ 7.8878837, -8.405592 ], dtype=float32),
#  array([-2.248273,  2.852389], dtype=float32),
#  array([ 4.6727057, -4.8954973], dtype=float32),
#  array([ 4.730634, -4.958766], dtype=float32),
#  array([-2.3915539,  3.0180979], dtype=float32),
#  array([ 6.423314 , -6.8066325], dtype=float32),
#  array([ 6.2860875, -6.6568594], dtype=float32),
#  array([ 3.7954829, -3.9358099], dtype=float32),
#  array([ 6.373328, -6.752138], dtype=float32),
#  array([ 4.952444, -5.200921], dtype=float32),
#  array([ 7.5306067, -8.015611 ], dtype=float32),
#  array([ 5.9727244, -6.314811 ], dtype=float32),
#  array([ 6.36634 , -6.744517], dtype=float32),
#  array([ 4.650087 , -4.8708663], dtype=float32),
#  array([-2.5073168,  3.1522868], dtype=float32),
#  array([ 4.9749413, -5.225422 ], dtype=float32),
#  array([ 3.1041956, -3.1749623], dtype=float32),
#  array([ 3.276169 , -3.3643534], dtype=float32),
#  array([ 9.044191, -9.668764], dtype=float32),
#  array([ 4.258619, -4.443506], dtype=float32),
#  array([ 5.1012077, -5.3633723], dtype=float32),
#  array([-2.4140162,  3.0441585], dtype=float32),
#  array([ 6.01557  , -6.3615403], dtype=float32),
#  array([ 7.492864 , -7.9743567], dtype=float32),
#  array([ 6.4885335, -6.877927 ], dtype=float32),
#  array([ 4.977481 , -5.2282286], dtype=float32),
#  array([ 0.9144159 , -0.70716214], dtype=float32),
#  array([ 5.472566 , -5.7687087], dtype=float32),
#  array([ 6.6732492, -7.079517 ], dtype=float32),
#  array([ 5.2083354, -5.480312 ], dtype=float32),
#  array([ 5.1067214, -5.369362 ], dtype=float32),
#  array([ 4.4209623, -4.621118 ], dtype=float32),
#  array([ 5.9040594, -6.2398605], dtype=float32),
#  array([ 3.4975748, -3.6085527], dtype=float32),
#  array([ 5.4027762, -5.692608 ], dtype=float32),
#  array([ 5.265222, -5.542338], dtype=float32),
#  array([ 9.033644, -9.657328], dtype=float32),
#  array([ 7.2506924, -7.709965 ], dtype=float32),
#  array([ 5.950594 , -6.2906156], dtype=float32),
#  array([ 5.0990515, -5.360963 ], dtype=float32),
#  array([ 4.018826 , -4.1806483], dtype=float32),
#  array([ 4.168054, -4.34444 ], dtype=float32),
#  array([ 5.267564 , -5.5449567], dtype=float32),
#  array([ 6.5100255, -6.9013815], dtype=float32),
#  array([ 4.010783, -4.171627], dtype=float32),
#  array([ 5.869976 , -6.2026067], dtype=float32),
#  array([ 5.129929, -5.394747], dtype=float32),
#  array([ 5.704299, -6.021752], dtype=float32),
#  array([ 3.374794, -3.472917], dtype=float32),
#  array([ 4.5103545, -4.718539 ], dtype=float32),
#  array([ 7.126176, -7.574015], dtype=float32),
#  array([ 4.766108 , -4.9974246], dtype=float32),
#  array([ 7.2438455, -7.7025766], dtype=float32),
#  array([ 5.812035 , -6.1393723], dtype=float32),
#  array([ 4.7774763, -5.009913 ], dtype=float32),
#  array([ 6.0906243, -6.443465 ], dtype=float32),
#  array([ 4.9592156, -5.2082825], dtype=float32),
#  array([-1.5492725,  2.0701354], dtype=float32),
#  array([ 4.8719068, -5.112988 ], dtype=float32),
#  array([ 5.1573806, -5.4246593], dtype=float32),
#  array([ 5.755219 , -6.0773864], dtype=float32),
#  array([ 5.0424213, -5.2991276], dtype=float32),
#  array([ 5.3037667, -5.5843983], dtype=float32),
#  array([ 6.0488615, -6.397924 ], dtype=float32),
#  array([-2.498359 ,  3.1419115], dtype=float32),
#  array([ 7.591054, -8.081536], dtype=float32),
#  array([ 6.750929, -7.16436 ], dtype=float32),
#  array([ 2.9027839, -2.952342 ], dtype=float32),
#  array([ 3.5579216, -3.6746624], dtype=float32),
#  array([ 3.862395, -4.009224], dtype=float32),
#  array([ 5.769105, -6.09244 ], dtype=float32),
#  array([ 3.612863 , -3.7353814], dtype=float32),
#  array([ 7.5782065, -8.067585 ], dtype=float32),
#  array([ 5.9119134, -6.24843  ], dtype=float32),
#  array([ 7.8324795, -8.345134 ], dtype=float32),
#  array([ 4.555545 , -4.7677455], dtype=float32),
#  array([ 5.0703344, -5.329554 ], dtype=float32),
#  array([ 4.8269362, -5.0638766], dtype=float32),
#  array([ 4.88843  , -5.1310115], dtype=float32),
#  array([-0.87810975,  1.3145849 ], dtype=float32),
#  array([-2.1205456,  2.7048585], dtype=float32),
#  array([ 6.2387996, -6.6052833], dtype=float32),
#  array([ 5.7778625, -6.101998 ], dtype=float32),
#  array([ 4.732448, -4.960699], dtype=float32),
#  array([ 6.701038 , -7.1099443], dtype=float32),
#  array([ 5.5269966, -5.828136 ], dtype=float32),
#  array([-1.9715157,  2.53246  ], dtype=float32),
#  array([-2.5245714,  3.1723795], dtype=float32),
#  array([ 7.77521, -8.2826 ], dtype=float32),
#  array([ 4.829695 , -5.0669675], dtype=float32),
#  array([ 4.231487, -4.413572], dtype=float32),
#  array([ 4.839315, -5.077396], dtype=float32),
#  array([ 5.1120925, -5.375239 ], dtype=float32),
#  array([ 5.5088296, -5.808366 ], dtype=float32),
#  array([ 4.554626, -4.766743], dtype=float32),
#  array([ 0.90538883, -0.6984099 ], dtype=float32),
#  array([ 3.0663803, -3.1336484], dtype=float32),
#  array([ 3.8944118, -4.0442557], dtype=float32),
#  array([-2.2086718,  2.8066354], dtype=float32),
#  array([-1.8098497,  2.3454359], dtype=float32),
#  array([ 3.6152275, -3.7379239], dtype=float32),
#  array([ 4.188944, -4.367139], dtype=float32),
#  array([ 3.9670782, -4.1239166], dtype=float32),
#  array([-2.397782 ,  3.0253854], dtype=float32),
#  array([ 4.341074, -4.533717], dtype=float32),
#  array([ 4.711067 , -4.9374266], dtype=float32),
#  array([ 4.8011885, -5.0358   ], dtype=float32),
#  array([ 3.9593756, -4.115567 ], dtype=float32),
#  array([ 7.9088616, -8.428574 ], dtype=float32),
#  array([ 5.7268367, -6.0462966], dtype=float32),
#  array([ 3.422332 , -3.5254474], dtype=float32),
#  array([ 4.5885215, -4.803686 ], dtype=float32),
#  array([ 6.1509247, -6.5093327], dtype=float32),
#  array([ 5.662814, -5.976452], dtype=float32),
#  array([ 5.2724924, -5.5503926], dtype=float32),
#  array([ 6.169209, -6.529339], dtype=float32),
#  array([ 5.2698407, -5.547393 ], dtype=float32),
#  array([ 5.9149704, -6.251732 ], dtype=float32),
#  array([ 7.5686555, -8.057089 ], dtype=float32),
#  array([ 5.9674473, -6.3090363], dtype=float32),
#  array([ 5.2794685, -5.557941 ], dtype=float32),
#  array([ 5.0197587, -5.274462 ], dtype=float32),
#  array([ 7.5255213, -8.009969 ], dtype=float32),
#  array([ 5.3870955, -5.67542  ], dtype=float32),
#  array([-2.5083601,  3.1535084], dtype=float32),
#  array([ 4.9548416, -5.203515 ], dtype=float32),
#  array([ 5.0800524, -5.3402224], dtype=float32),
#  array([ 4.6137047, -4.8310966], dtype=float32),
#  array([ 6.338826, -6.714489], dtype=float32),
#  array([-0.661208,  1.069113], dtype=float32),
#  array([ 5.4729323, -5.769126 ], dtype=float32),
#  array([ 6.373552, -6.752389], dtype=float32),
#  array([ 4.6461296, -4.8664804], dtype=float32),
#  array([ 5.5886574, -5.895481 ], dtype=float32),
#  array([ 4.9869165, -5.238532 ], dtype=float32),
#  array([-1.9960155,  2.5607605], dtype=float32),
#  array([ 4.548691, -4.760349], dtype=float32),
#  array([ 5.8467255, -6.177253 ], dtype=float32),
#  array([ 4.2062373, -4.3858714], dtype=float32),
#  array([ 5.7308755, -6.050711 ], dtype=float32),
#  array([ 4.9874215, -5.2390876], dtype=float32),
#  array([ 4.6805763, -4.9041047], dtype=float32),
#  array([ 6.119528, -6.475081], dtype=float32),
#  array([ 4.638765 , -4.8584347], dtype=float32),
#  array([-2.1146607,  2.698063 ], dtype=float32),
#  array([ 3.866473, -4.013445], dtype=float32),
#  array([ 3.0837622, -3.151966 ], dtype=float32),
#  array([ 7.0559397, -7.497356 ], dtype=float32),
#  array([ 6.041165, -6.389427], dtype=float32),
#  array([ 4.6962395, -4.921226 ], dtype=float32),
#  array([ 2.3866081, -2.3682165], dtype=float32),
#  array([ 5.0769744, -5.336844 ], dtype=float32),
#  array([ 5.782604 , -6.1071873], dtype=float32),
#  array([ 8.342255, -8.901712], dtype=float32),
#  array([ 0.6005944 , -0.35395548], dtype=float32),
#  array([ 8.306905, -8.863114], dtype=float32),
#  array([ 4.863002 , -5.1032677], dtype=float32),
#  array([ 5.6582737, -5.97149  ], dtype=float32),
#  array([ 8.610039, -9.194401], dtype=float32),
#  array([ 5.752524 , -6.0744295], dtype=float32),
#  array([ 10.806129, -11.594269], dtype=float32),
#  array([-2.4122076,  3.041977 ], dtype=float32),
#  array([ 4.294625 , -4.4828143], dtype=float32),
#  array([-2.5345953,  3.183983 ], dtype=float32),
#  array([ 5.1910214, -5.461362 ], dtype=float32),
#  array([ 4.715648, -4.942366], dtype=float32),
#  array([ 5.3560715, -5.641598 ], dtype=float32),
#  array([ 4.997529, -5.250115], dtype=float32),
#  array([ 3.9587998, -4.1146946], dtype=float32),
#  array([ 5.6891885, -6.005274 ], dtype=float32),
#  array([ 3.2016191, -3.2819483], dtype=float32),
#  array([ 3.6023123, -3.7238798], dtype=float32),
#  array([ 4.534823 , -4.7452455], dtype=float32),
#  array([ 5.6959643, -6.0125732], dtype=float32),
#  array([ 7.423132 , -7.8982015], dtype=float32),
#  array([ 4.687457 , -4.9116282], dtype=float32),
#  array([ 4.096381, -4.265582], dtype=float32),
#  array([ 5.659376, -5.972771], dtype=float32),
#  array([ 5.7364006, -6.05677  ], dtype=float32),
#  array([ 6.3572674, -6.7346344], dtype=float32),
#  array([ 5.104604, -5.367073], dtype=float32),
#  array([ 7.125081, -7.572853], dtype=float32),
#  array([ 4.7622943, -4.993312 ], dtype=float32),
#  array([ 9.0048275, -9.625861 ], dtype=float32),
#  array([ 6.0587   , -6.4086537], dtype=float32),
#  array([ 6.989138 , -7.4244576], dtype=float32),
#  array([ 4.7192564, -4.9463634], dtype=float32),
#  array([ 6.596074, -6.995294], dtype=float32),
#  array([ 5.0779147, -5.3378606], dtype=float32),
#  array([ 5.7784233, -6.1026807], dtype=float32),
#  array([ 5.346235, -5.630787], dtype=float32),
#  array([-1.0882971,  1.5514898], dtype=float32),
#  array([ 6.37392  , -6.7527585], dtype=float32),
#  array([ 4.198128 , -4.3770547], dtype=float32),
#  array([ 3.9312446, -4.084576 ], dtype=float32),
#  array([ 4.7311497, -4.9592724], dtype=float32),
#  array([ 2.5746171, -2.5826638], dtype=float32),
#  array([ 4.955732, -5.204484], dtype=float32),
#  array([ 6.3311706, -6.706034 ], dtype=float32),
#  array([ 4.9856315, -5.237107 ], dtype=float32),
#  array([ 4.4890814, -4.6953707], dtype=float32),
#  array([-2.5021188,  3.146241 ], dtype=float32),
#  array([ 3.4121752, -3.5142546], dtype=float32),
#  array([ 5.3730793, -5.660112 ], dtype=float32),
#  array([-2.5228631,  3.170351 ], dtype=float32),
#  array([ 7.107885 , -7.5541058], dtype=float32),
#  array([ 6.258665 , -6.6269503], dtype=float32),
#  array([ 5.799844 , -6.1260843], dtype=float32),
#  array([ 7.297225, -7.760754], dtype=float32),
#  array([ 6.037053, -6.385022], dtype=float32),
#  array([ 2.9752913, -3.0327177], dtype=float32),
#  array([ 4.9001746, -5.143818 ], dtype=float32),
#  array([ 6.987533 , -7.4226184], dtype=float32),
#  array([-2.507418,  3.152414], dtype=float32),
#  array([ 4.7745924, -5.0067515], dtype=float32),
#  array([ 4.567137, -4.7803  ], dtype=float32),
#  array([ 4.0779996, -4.2455177], dtype=float32),
#  array([ 5.1934166, -5.4639783], dtype=float32),
#  array([-1.7001984,  2.233471 ], dtype=float32),
#  array([ 4.2166677, -4.397381 ], dtype=float32),
#  array([-0.9341007,  1.3778849], dtype=float32),
#  array([ 3.9968739, -4.1566215], dtype=float32),
#  array([ 7.120037 , -7.5673194], dtype=float32),
#  array([ 6.67726 , -7.083948], dtype=float32),
#  array([ 4.7598386, -4.991002 ], dtype=float32),
#  array([0.23695959, 0.0561823 ], dtype=float32),
#  array([-1.845514,  2.386803], dtype=float32),
#  array([ 5.688704, -6.00468 ], dtype=float32),
#  array([ 7.896301 , -8.4148245], dtype=float32),
#  array([ 1.7375467, -1.6344925], dtype=float32),
#  array([ 3.0950365, -3.1647387], dtype=float32),
#  array([ 5.5515256, -5.8549075], dtype=float32),
#  array([ 7.4623446, -7.941046 ], dtype=float32),
#  array([ 6.407828, -6.789751], dtype=float32),
#  array([ 4.093433, -4.262284], dtype=float32),
#  array([ 4.3953304, -4.593182 ], dtype=float32),
#  array([ 3.2799213, -3.3682883], dtype=float32),
#  array([ 3.4318502, -3.5359545], dtype=float32),
#  array([ 4.812206 , -5.0477915], dtype=float32),
#  array([ 4.913214 , -5.1580606], dtype=float32),
#  array([ 5.873173 , -6.2060966], dtype=float32),
#  array([ 5.492982 , -5.7910137], dtype=float32),
#  array([-0.49191535,  0.8796569 ], dtype=float32),
#  array([ 6.4910617, -6.880722 ], dtype=float32),
#  array([ 4.5709696, -4.7844987], dtype=float32),
#  array([ 6.0723615, -6.423572 ], dtype=float32),
#  array([ 4.8966546, -5.1399784], dtype=float32),
#  array([-1.9221363,  2.4752805], dtype=float32),
#  array([ 6.896854, -7.323706], dtype=float32),
#  array([ 6.3747625, -6.7536373], dtype=float32),
#  array([ 4.985785 , -5.2372932], dtype=float32),
#  array([ 4.266849, -4.452431], dtype=float32),
#  array([ 2.1492002, -2.100538 ], dtype=float32),
#  array([-2.5381892,  3.1881266], dtype=float32),
#  array([ 4.7600503, -4.9908357], dtype=float32),
#  array([ 4.7657223, -4.997138 ], dtype=float32),
#  array([ 7.077002 , -7.5203676], dtype=float32),
#  array([-2.5375624,  3.187467 ], dtype=float32),
#  array([ 5.2197766, -5.49271  ], dtype=float32),
#  array([ 3.479995 , -3.5890057], dtype=float32),
#  array([ 4.661736 , -4.8835497], dtype=float32),
#  array([ 5.89457  , -6.2295213], dtype=float32),
#  array([ 7.107168 , -7.5532436], dtype=float32),
#  array([ 5.1507416, -5.4173355], dtype=float32),
#  array([ 5.46647, -5.76211], dtype=float32),
#  array([-2.521662 ,  3.1689315], dtype=float32),
#  array([-0.8641506,  1.2984725], dtype=float32),
#  array([ 6.755487, -7.169368], dtype=float32),
#  array([ 5.4539194, -5.7483745], dtype=float32),
#  array([ 2.2978613, -2.2682946], dtype=float32),
#  array([ 7.0454903, -7.485956 ], dtype=float32),
#  array([ 3.778227 , -3.9167202], dtype=float32),
#  array([ 5.0010805, -5.2540336], dtype=float32),
#  array([ 5.9640713, -6.3053346], dtype=float32),
#  array([-2.0988653,  2.6800134], dtype=float32),
#  array([ 5.0525956, -5.310209 ], dtype=float32),
#  array([ 5.949817 , -6.2897787], dtype=float32),
#  array([ 4.6930385, -4.9177256], dtype=float32),
#  array([ 4.9571967, -5.206178 ], dtype=float32),
#  array([ 4.8723817, -5.1135364], dtype=float32),
#  array([ 7.0219064, -7.46016  ], dtype=float32),
#  array([ 5.872325 , -6.2051997], dtype=float32),
#  array([ 4.138076 , -4.3111634], dtype=float32),
#  array([-2.503495 ,  3.1478512], dtype=float32),
#  array([ 4.722371, -4.949775], dtype=float32),
#  array([ 4.6677027, -4.8900995], dtype=float32),
#  array([-2.499899 ,  3.1436722], dtype=float32),
#  array([ 6.1491423, -6.5073395], dtype=float32),
#  array([ 6.6114736, -7.0121465], dtype=float32),
#  array([ 6.5129557, -6.9045596], dtype=float32),
#  array([ 4.7309484, -4.9590883], dtype=float32),
#  array([ 6.5000443, -6.8904243], dtype=float32),
#  array([ 5.2181416, -5.4909616], dtype=float32),
#  array([ 5.007189 , -5.2606926], dtype=float32),
#  array([ 4.0289583, -4.191705 ], dtype=float32),
#  array([ 4.759913 , -4.9907336], dtype=float32),
#  array([-2.2965126,  2.9080846], dtype=float32),
#  array([ 5.0025964, -5.255608 ], dtype=float32),
#  array([ 4.254844, -4.439294], dtype=float32),
#  array([ 5.4415054, -5.734834 ], dtype=float32),
#  array([ 4.855081 , -5.0945716], dtype=float32),
#  array([ 3.7276511, -3.8611856], dtype=float32),
#  array([ 6.8683085, -7.292593 ], dtype=float32),
#  array([ 4.8481426, -5.0869756], dtype=float32),
#  array([-2.2898319,  2.9004767], dtype=float32),
#  array([-2.5056295,  3.1503415], dtype=float32),
#  array([ 5.786023 , -6.1109548], dtype=float32),
#  array([-2.5174794,  3.1640947], dtype=float32),
#  array([-2.088707 ,  2.6682093], dtype=float32),
#  array([ 3.421443 , -3.5243983], dtype=float32),
#  array([ 6.8284607, -7.2491064], dtype=float32),
#  array([ 6.7863517, -7.2031045], dtype=float32),
#  array([ 5.2038136, -5.475308 ], dtype=float32),
#  array([-2.5058086,  3.150533 ], dtype=float32),
#  array([ 5.2493763, -5.52508  ], dtype=float32),
#  array([ 4.7750354, -5.0072327], dtype=float32),
#  array([ 4.548003 , -4.7594795], dtype=float32),
#  array([ 5.3817997, -5.6696067], dtype=float32),
#  array([ 7.1041126, -7.550013 ], dtype=float32),
#  array([ 6.8162594, -7.235683 ], dtype=float32),
#  array([ 5.3220005, -5.6043677], dtype=float32),
#  array([ 5.0414166, -5.2980814], dtype=float32),
#  array([ 7.765965, -8.272558], dtype=float32),
#  array([ 4.45168  , -4.6546907], dtype=float32),
#  array([ 5.689051, -6.005006], dtype=float32),
#  array([-2.2334173,  2.8351188], dtype=float32),
#  array([ 6.3058505, -6.6784678], dtype=float32),
#  array([ 5.0272818, -5.282594 ], dtype=float32),
#  array([ 4.833059 , -5.0706096], dtype=float32),
#  array([ 4.4919605, -4.698494 ], dtype=float32),
#  array([ 5.7862973, -6.111262 ], dtype=float32),
#  array([ 6.812263 , -7.2313476], dtype=float32),
#  array([ 3.9549713, -4.1105294], dtype=float32),
#  array([ 5.844457, -6.174677], dtype=float32),
#  array([ 4.9994884, -5.2522664], dtype=float32),
#  array([ 3.0582063, -3.1240356], dtype=float32),
#  array([ 4.7041   , -4.9297395], dtype=float32),
#  array([ 5.173464, -5.442194], dtype=float32),
#  array([ 3.7841027, -3.9232693], dtype=float32),
#  array([ 5.0774217, -5.3373404], dtype=float32),
#  array([ 2.1679225, -2.1211078], dtype=float32),
#  array([ 6.0173206, -6.363423 ], dtype=float32),
#  array([ 4.2318087, -4.4137144], dtype=float32),
#  array([ 3.794436 , -3.9345036], dtype=float32),
#  array([ 4.3252125, -4.516432 ], dtype=float32),
#  array([ 5.7862887, -6.111179 ], dtype=float32),
#  array([ 4.8513613, -5.0905867], dtype=float32),
#  array([-2.5323963,  3.181434 ], dtype=float32),
#  array([ 4.907526, -5.151878], dtype=float32),
#  array([ 4.6608114, -4.8825064], dtype=float32),
#  array([ 5.2648864, -5.5420504], dtype=float32),
#  array([ 6.353306, -6.730251], dtype=float32),
#  array([ 5.9975715, -6.341963 ], dtype=float32),
#  array([ 6.0142264, -6.3600845], dtype=float32),
#  array([-2.499483 ,  3.1432176], dtype=float32),
#  array([ 2.7374132, -2.766782 ], dtype=float32),
#  array([-2.5125868,  3.158389 ], dtype=float32),
#  array([ 8.216836, -8.764773], dtype=float32),
#  array([-1.6288416,  2.1540658], dtype=float32),
#  array([ 4.5381594, -4.748877 ], dtype=float32),
#  array([ 2.8871677, -2.9352717], dtype=float32),
#  array([ 4.9921823, -5.2442713], dtype=float32),
#  array([ 4.700364, -4.925675], dtype=float32),
#  array([ 5.9421916, -6.281436 ], dtype=float32),
#  array([ 4.3538394, -4.5476346], dtype=float32),
#  array([ 4.724297, -4.951783], dtype=float32),
#  array([ 5.369739 , -5.6564655], dtype=float32),
#  array([ 6.1662235, -6.526105 ], dtype=float32),
#  array([ 7.671294, -8.169236], dtype=float32),
#  array([-2.1491983,  2.7379174], dtype=float32),
#  array([ 4.6080413, -4.8249345], dtype=float32),
#  array([ 6.0137153, -6.359501 ], dtype=float32),
#  array([ 7.7583666, -8.264155 ], dtype=float32),
#  array([ 7.862767, -8.37824 ], dtype=float32),
#  array([ 5.795024, -6.120859], dtype=float32),
#  array([-2.5291097,  3.1775959], dtype=float32),
#  array([ 7.136268, -7.585052], dtype=float32),
#  array([ 5.087856 , -5.3487463], dtype=float32),
#  array([ 4.8809347, -5.122828 ], dtype=float32),
#  array([ 5.74641 , -6.067718], dtype=float32),
#  array([ 4.5254197, -4.734995 ], dtype=float32),
#  array([-2.5017936,  3.1458814], dtype=float32),
#  array([-2.3773296,  3.0016203], dtype=float32),
#  array([ 5.7830377, -6.107676 ], dtype=float32),
#  array([-1.9520187,  2.5099814], dtype=float32),
#  array([ 4.6665077, -4.8887396], dtype=float32),
#  array([-2.5123188,  3.1581163], dtype=float32),
#  array([ 6.440845 , -6.8258414], dtype=float32),
#  array([ 4.882508 , -5.1245832], dtype=float32),
#  array([ 2.6959577, -2.7187366], dtype=float32),
#  array([ 7.138054, -7.58704 ], dtype=float32),
#  array([ 5.5076866, -5.80706  ], dtype=float32),
#  array([ 5.372866, -5.659899], dtype=float32),
#  array([ 4.407697 , -4.6067047], dtype=float32),
#  array([ 3.7741594, -3.9125738], dtype=float32),
#  array([ 2.8477814, -2.892597 ], dtype=float32),
#  array([-1.6309004,  2.1569407], dtype=float32),
#  array([ 5.4831667, -5.780323 ], dtype=float32),
#  array([ 5.867665 , -6.2000833], dtype=float32),
#  array([ 3.0387802, -3.1028152], dtype=float32),
#  array([ 2.9355745, -2.9887705], dtype=float32),
#  array([ 6.4782104, -6.866651 ], dtype=float32),
#  array([-2.3645258,  2.9868426], dtype=float32),
#  array([-2.474173 ,  3.1138473], dtype=float32),
#  array([ 6.635702, -7.038585], dtype=float32),
#  array([ 3.2760634, -3.3639455], dtype=float32),
#  array([ 5.7566304, -6.0788918], dtype=float32),
#  array([ 6.22223  , -6.5871305], dtype=float32),
#  array([  9.936038, -10.643582], dtype=float32),
#  array([ 4.600523 , -4.8167543], dtype=float32),
#  array([ 7.503783 , -7.9862947], dtype=float32),
#  array([ 6.1098747, -6.464512 ], dtype=float32),
#  array([ 5.91695, -6.25391], dtype=float32),
#  array([ 6.6942134, -7.1024303], dtype=float32),
#  array([ 5.6182246, -5.927774 ], dtype=float32),
#  array([ 7.017146, -7.455043], dtype=float32),
#  array([ 6.1275783, -6.483904 ], dtype=float32),
#  array([ 5.743354, -6.064393], dtype=float32),
#  array([ 4.85821 , -5.098092], dtype=float32),
#  array([ 4.9175487, -5.1628036], dtype=float32),
#  array([ 8.163917, -8.707038], dtype=float32),
#  array([ 5.814341 , -6.1418324], dtype=float32),
#  array([ 5.90713 , -6.243227], dtype=float32),
#  array([ 5.1394234, -5.4050455], dtype=float32),
#  array([ 5.7597065, -6.082286 ], dtype=float32),
#  array([ 5.6148787, -5.924089 ], dtype=float32),
#  array([ 3.8726301, -4.020312 ], dtype=float32),
#  array([ 5.648606, -5.960951], dtype=float32),
#  array([ 4.5956826, -4.8114505], dtype=float32),
#  array([ 8.415876, -8.982265], dtype=float32),
#  array([ 8.411996, -8.977943], dtype=float32),
#  array([-1.9293618,  2.4836767], dtype=float32),
#  array([ 5.942772, -6.282083], dtype=float32),
#  array([ 5.7374287, -6.0578985], dtype=float32),
#  array([ 4.231693, -4.413596], dtype=float32),
#  array([ 5.2068796, -5.478697 ], dtype=float32),
#  array([ 1.3057077, -1.1482844], dtype=float32),
#  array([ 3.7912066, -3.930997 ], dtype=float32),
#  array([ 5.7574635, -6.0798435], dtype=float32),
#  array([ 6.450048 , -6.8358703], dtype=float32),
#  array([ 6.137055 , -6.4941673], dtype=float32),
#  array([ 4.84147 , -5.079731], dtype=float32),
#  array([ 4.803434, -5.038231], dtype=float32),
#  array([ 6.5693097, -6.966035 ], dtype=float32),
#  array([0.19981197, 0.09846587], dtype=float32),
#  array([ 5.4271703, -5.719184 ], dtype=float32),
#  array([ 4.8576646, -5.097442 ], dtype=float32),
#  array([ 7.0162435, -7.45403  ], dtype=float32),
#  array([ 4.753499, -4.983706], dtype=float32),
#  array([ 4.5238805, -4.7333784], dtype=float32),
#  array([ 3.8915737, -4.0411234], dtype=float32),
#  array([ 5.555458, -5.859205], dtype=float32),
#  array([-2.347524 ,  2.9672422], dtype=float32),
#  array([ 3.4102695, -3.5118916], dtype=float32),
#  array([ 5.89739 , -6.232519], dtype=float32),
#  array([ 4.4351764, -4.6366787], dtype=float32),
#  array([ 5.297297, -5.577375], dtype=float32),
#  array([-2.15239 ,  2.741781], dtype=float32),
#  array([ 5.5481253, -5.851211 ], dtype=float32),
#  array([ 5.193464, -5.463975], dtype=float32),
#  array([ 3.8641403, -4.011131 ], dtype=float32),
#  array([ 5.594532, -5.901862], dtype=float32),
#  array([ 6.128907, -6.485349], dtype=float32),
#  array([-1.9756758,  2.5373712], dtype=float32),
#  array([ 4.7631383, -4.9942904], dtype=float32),
#  array([ 7.4458027, -7.9229608], dtype=float32),
#  array([ 3.342259 , -3.4368846], dtype=float32),
#  array([ 7.589961 , -8.0804205], dtype=float32),
#  array([ 5.7580743, -6.0804253], dtype=float32),
#  array([ 5.7014318, -6.018599 ], dtype=float32),
#  array([ 6.8411403, -7.262775 ], dtype=float32),
#  array([ 5.4273376, -5.7192726], dtype=float32),
#  array([ 2.8639753, -2.9100072], dtype=float32),
#  array([ 7.735922, -8.239738], dtype=float32),
#  array([ 5.3145494, -5.5962715], dtype=float32),
#  array([ 4.2498093, -4.433571 ], dtype=float32),
#  array([ 4.009271 , -4.1703053], dtype=float32),
#  array([ 4.907184, -5.151501], dtype=float32),
#  array([ 5.117132 , -5.3807282], dtype=float32),
#  array([ 6.6562753, -7.0609984], dtype=float32),
#  array([ 5.206578, -5.47838 ], dtype=float32),
#  array([ 4.454256, -4.657432], dtype=float32),
#  array([ 5.676728, -5.991633], dtype=float32),
#  array([ 6.343723 , -6.7198133], dtype=float32),
#  array([ 4.050469, -4.215442], dtype=float32),
#  array([ 5.9701004, -6.311881 ], dtype=float32),
#  array([ 3.7699509, -3.907678 ], dtype=float32),
#  array([ 4.537257, -4.747908], dtype=float32),
#  array([ 5.976909 , -6.3193474], dtype=float32),
#  array([ 4.360316 , -4.5547576], dtype=float32),
#  array([ 5.858472 , -6.1900344], dtype=float32),
#  array([ 6.4339623, -6.818354 ], dtype=float32),
#  array([ 5.5495434, -5.852737 ], dtype=float32),
#  array([ 4.6582527, -4.879791 ], dtype=float32),
#  array([ 6.235901 , -6.6021037], dtype=float32),
#  array([-2.2101357,  2.808448 ], dtype=float32),
#  array([ 5.117234, -5.380838], dtype=float32),
#  array([ 5.0427446, -5.2994833], dtype=float32),
#  array([  9.854921, -10.554772], dtype=float32),
#  array([ 7.04783 , -7.488487], dtype=float32),
#  array([ 3.742718, -3.877704], dtype=float32),
#  array([ 5.548453, -5.851559], dtype=float32),
#  array([ 3.4294927, -3.5335138], dtype=float32),
#  array([ 5.102835 , -5.3651805], dtype=float32),
#  array([ 4.9219966, -5.1677046], dtype=float32),
#  array([ 4.8244357, -5.0611873], dtype=float32),
#  array([-2.5124311,  3.1582103], dtype=float32),
#  array([ 5.96087 , -6.301821], dtype=float32),
#  array([ 4.956468, -5.205275], dtype=float32),
#  array([ 5.090984 , -5.3521333], dtype=float32),
#  array([-1.6004081,  2.1243825], dtype=float32),
#  array([ 6.7019553, -7.110932 ], dtype=float32),
#  array([ 4.7441716, -4.973527 ], dtype=float32),
#  array([ 4.5578437, -4.770247 ], dtype=float32),
#  array([ 5.3680816, -5.6546454], dtype=float32),
#  array([ 4.0288434, -4.191666 ], dtype=float32),
#  array([-2.513355 ,  3.1593003], dtype=float32),
#  array([ 2.8885572, -2.936957 ], dtype=float32),
#  array([ 5.717488, -6.036137], dtype=float32),
#  array([ 4.4275055, -4.62829  ], dtype=float32),
#  array([-2.5208528,  3.1680284], dtype=float32),
#  array([ 6.1079254, -6.462375 ], dtype=float32),
#  array([-2.3185008,  2.933564 ], dtype=float32),
#  array([ 5.903891 , -6.2395916], dtype=float32),
#  array([ 4.612832 , -4.8302073], dtype=float32),
#  array([ 4.0393767, -4.2030396], dtype=float32),
#  array([ 4.8859644, -5.1283784], dtype=float32),
#  array([ 5.8338485, -6.1631517], dtype=float32),
#  array([ 5.3050632, -5.5858817], dtype=float32),
#  array([ 6.6418614, -7.045248 ], dtype=float32),
#  array([ 5.9680657, -6.3097386], dtype=float32),
#  array([ 4.751171 , -4.9812126], dtype=float32),
#  array([ 5.812216 , -6.1395445], dtype=float32),
#  array([ 4.2700233, -4.4560947], dtype=float32),
#  array([ 4.0224023, -4.184481 ], dtype=float32),
#  array([ 6.6400294, -7.0433974], dtype=float32),
#  array([ 3.875095 , -4.0230527], dtype=float32),
#  array([ 4.509046, -4.717079], dtype=float32),
#  array([ 6.3696365, -6.748105 ], dtype=float32),
#  array([-1.8275063,  2.3658803], dtype=float32),
#  array([ 5.5009336, -5.799691 ], dtype=float32),
#  array([ 3.5919113, -3.7126086], dtype=float32),
#  array([-2.2389925,  2.841652 ], dtype=float32),
#  array([ 5.322822, -5.605258], dtype=float32),
#  array([-0.7983454,  1.2252108], dtype=float32),
#  array([ 5.845623, -6.176013], dtype=float32),
#  array([ 4.1798205, -4.356951 ], dtype=float32),
#  array([ 4.94603 , -5.193916], dtype=float32),
#  array([ 6.9341354, -7.364414 ], dtype=float32),
#  array([ 8.692213, -9.28424 ], dtype=float32),
#  array([ 5.729847 , -6.0496297], dtype=float32),
#  array([ 5.2139654, -5.4863815], dtype=float32),
#  array([ 5.102483, -5.364707], dtype=float32),
#  array([ 6.360998 , -6.7386823], dtype=float32),
#  array([-2.4389465,  3.0730424], dtype=float32),
#  array([-1.6000593,  2.1232233], dtype=float32),
#  array([ 4.8891263, -5.1317782], dtype=float32),
#  array([ 5.4738836, -5.7701764], dtype=float32),
#  array([ 5.2157755, -5.488383 ], dtype=float32),
#  array([ 4.708656 , -4.9346833], dtype=float32),
#  array([ 6.078246 , -6.4300194], dtype=float32),
#  array([ 1.4488335, -1.3092079], dtype=float32),
#  array([ 4.366479 , -4.5615315], dtype=float32),
#  array([ 4.5938363, -4.809668 ], dtype=float32),
#  array([ 4.806948, -5.042046], dtype=float32),
#  array([ 5.0871286, -5.348004 ], dtype=float32),
#  array([ 6.655211 , -7.0599227], dtype=float32),
#  array([ 4.1681576, -4.344322 ], dtype=float32),
#  array([ 7.023918 , -7.4624496], dtype=float32),
#  array([ 4.9714527, -5.2216697], dtype=float32),
#  array([-2.437648 ,  3.0714386], dtype=float32),
#  array([ 6.314833, -6.688276], dtype=float32),
#  array([ 5.0717893, -5.3312383], dtype=float32),
#  array([ 5.1010923, -5.363273 ], dtype=float32),
#  array([-2.5111225,  3.1567485], dtype=float32),
#  array([ 5.7283177, -6.0479784], dtype=float32),
#  array([ 5.419148, -5.710485], dtype=float32),
#  array([ 7.227405 , -7.6845436], dtype=float32),
#  array([ 4.349357 , -4.5426826], dtype=float32),
#  array([ 5.52317  , -5.8239326], dtype=float32),
#  array([ 6.9938455, -7.429556 ], dtype=float32),
#  array([ 7.8155627, -8.3266325], dtype=float32),
#  array([ 3.6573308, -3.7840803], dtype=float32),
#  array([ 7.996846 , -8.5246315], dtype=float32),
#  array([ 6.2488074, -6.61621  ], dtype=float32),
#  array([ 5.4717402, -5.767828 ], dtype=float32),
#  array([ 1.2223723, -1.0549392], dtype=float32),
#  array([ 6.2955413, -6.6672125], dtype=float32),
#  array([ 3.4599767, -3.5670378], dtype=float32),
#  array([-2.0204685,  2.5891297], dtype=float32),
#  array([ 5.2882323, -5.567534 ], dtype=float32),
#  array([ 5.683589, -5.99906 ], dtype=float32),
#  array([ 5.181922, -5.451441], dtype=float32),
#  array([ 3.8796034, -4.0281773], dtype=float32),
#  array([ 3.440023 , -3.5451047], dtype=float32),
#  array([ 4.0448375, -4.2091837], dtype=float32),
#  array([ 5.7016044, -6.0187936], dtype=float32),
#  array([ 6.663455, -7.068835], dtype=float32),
#  array([ 3.1054962, -3.1760583], dtype=float32),
#  array([ 4.521601 , -4.7307544], dtype=float32),
#  array([ 6.1181016, -6.4734626], dtype=float32),
#  array([ 7.0253053, -7.4639406], dtype=float32),
#  array([ 3.871304 , -4.0188074], dtype=float32),
#  array([-0.7279255,  1.1440449], dtype=float32),
#  array([ 5.550753, -5.854136], dtype=float32),
#  array([ 4.817698 , -5.0537996], dtype=float32),
#  array([ 6.4644094, -6.851669 ], dtype=float32),
#  array([-2.493263 ,  3.1359437], dtype=float32),
#  array([ 4.1960077, -4.374648 ], dtype=float32),
#  array([ 5.218443 , -5.4913254], dtype=float32),
#  array([ 7.3342113, -7.8011417], dtype=float32),
#  array([ 5.6658072, -5.9796863], dtype=float32),
#  array([ 5.388715, -5.677162], dtype=float32),
#  array([ 6.0889077, -6.4416633], dtype=float32),
#  array([-2.5070736,  3.1520305], dtype=float32),
#  array([ 4.974131, -5.224603], dtype=float32),
#  array([ 7.814129, -8.325159], dtype=float32),
#  array([ 5.4651227, -5.760634 ], dtype=float32),
#  array([ 5.9597073, -6.300613 ], dtype=float32),
#  array([-2.285681 ,  2.8955932], dtype=float32),
#  array([ 5.4362607, -5.7291136], dtype=float32),
#  array([ 8.750453, -9.347777], dtype=float32),
#  array([ 4.87275, -5.11398], dtype=float32),
#  array([ 4.436809 , -4.6384645], dtype=float32),
#  array([ 6.664639 , -7.0701056], dtype=float32),
#  array([-1.5791502,  2.0991817], dtype=float32),
#  array([ 3.9574223, -4.113451 ], dtype=float32),
#  array([ 5.7568903, -6.079209 ], dtype=float32),
#  array([ 3.06607  , -3.1331103], dtype=float32),
#  array([-2.5156708,  3.1619718], dtype=float32),
#  array([ 5.474434, -5.770879], dtype=float32),
#  array([ 6.4047103, -6.786445 ], dtype=float32),
#  array([ 6.322928 , -6.6971455], dtype=float32),
#  array([ 3.766296 , -3.9035714], dtype=float32),
#  array([-1.9553196,  2.5138197], dtype=float32),
#  array([ 5.0316186, -5.2873383], dtype=float32),
#  array([ 5.3295326, -5.6125207], dtype=float32),
#  array([ 5.790266, -6.115576], dtype=float32),
#  array([ 5.489727, -5.787441], dtype=float32),
#  array([ 5.926085 , -6.2639084], dtype=float32),
#  array([ 5.334025 , -5.6175475], dtype=float32),
#  array([-2.5005896,  3.1444921], dtype=float32),
#  array([ 5.8055863, -6.132314 ], dtype=float32),
#  array([ 4.6465945, -4.867013 ], dtype=float32),
#  array([ 4.935789 , -5.1827226], dtype=float32),
#  array([-2.2626176,  2.8690083], dtype=float32),
#  array([-2.1259766,  2.711194 ], dtype=float32),
#  array([ 5.3356347, -5.619263 ], dtype=float32),
#  array([ 5.9198403, -6.2570286], dtype=float32),
#  array([ 6.0823965, -6.434527 ], dtype=float32),
#  array([ 4.500404 , -4.7076993], dtype=float32),
#  array([ 5.417657, -5.708836], dtype=float32),
#  array([-2.486868 ,  3.1285608], dtype=float32),
#  array([ 6.0875864, -6.440205 ], dtype=float32),
#  array([ 5.7583265, -6.0808268], dtype=float32),
#  array([ 3.5120122, -3.6243603], dtype=float32),
#  array([ 5.0417304, -5.2983603], dtype=float32),
#  array([ 4.5896225, -4.804943 ], dtype=float32),
#  array([ 5.3667717, -5.6532364], dtype=float32),
#  array([ 6.603518, -7.003408], dtype=float32),
#  array([ 6.5252857, -6.918005 ], dtype=float32),
#  array([ 5.7641153, -6.0869746], dtype=float32),
#  array([ 6.5035486, -6.894322 ], dtype=float32),
#  array([ 4.951029 , -5.1994214], dtype=float32),
#  array([ 7.4357696, -7.912076 ], dtype=float32),
#  array([ 4.376042 , -4.5718474], dtype=float32),
#  array([ 2.086508, -2.028605], dtype=float32),
#  array([ 4.6984353, -4.9236026], dtype=float32),
#  array([ 5.0434313, -5.30022  ], dtype=float32),
#  array([ 6.8940673, -7.3206563], dtype=float32),
#  array([ 4.6816235, -4.9052114], dtype=float32),
#  array([ 5.9685206, -6.310243 ], dtype=float32),
#  array([ 7.562554, -8.050459], dtype=float32),
#  array([ 6.1940484, -6.556411 ], dtype=float32),
#  array([-2.519861,  3.166873], dtype=float32),
#  array([ 6.9184895, -7.3473096], dtype=float32),
#  array([ 4.913938 , -5.1588497], dtype=float32),
#  array([ 4.6818476, -4.9055085], dtype=float32),
#  array([ 6.8885427, -7.314633 ], dtype=float32),
#  array([ 5.6547127, -5.9675565], dtype=float32),
#  array([ 4.156112 , -4.3311653], dtype=float32),
#  array([-2.5088756,  3.1540995], dtype=float32),
#  array([ 4.8761125, -5.117562 ], dtype=float32),
#  array([ 3.7800798, -3.9187703], dtype=float32),
#  array([ 4.0759153, -4.243316 ], dtype=float32),
#  array([ 6.513238 , -6.9048643], dtype=float32),
#  array([ 5.7208242, -6.039818 ], dtype=float32),
#  array([ 5.4702296, -5.7662363], dtype=float32),
#  array([ 4.26065  , -4.4456253], dtype=float32),
#  array([ 5.1693525, -5.437692 ], dtype=float32),
#  array([ 5.6704473, -5.9847417], dtype=float32),
#  array([ 5.9731708, -6.315171 ], dtype=float32),
#  array([ 3.5088656, -3.6208107], dtype=float32),
#  array([-2.3802347,  3.0049288], dtype=float32),
#  array([ 4.9003034, -5.1440268], dtype=float32),
#  array([ 5.397969 , -5.6873074], dtype=float32),
#  array([-2.4696176,  3.1085036], dtype=float32),
#  array([ 7.6759973, -8.174273 ], dtype=float32),
#  array([-2.5190005,  3.1658776], dtype=float32),
#  array([ 6.384074 , -6.7638264], dtype=float32),
#  array([ 4.44778  , -4.6505046], dtype=float32),
#  array([-1.1032224,  1.5678216], dtype=float32),
#  array([ 4.17723 , -4.354277], dtype=float32),
#  array([-2.45155  ,  3.0875654], dtype=float32),
#  array([ 3.7540252, -3.8900607], dtype=float32),
#  array([ 4.780857, -5.013561], dtype=float32),
#  array([ 4.9624   , -5.2117786], dtype=float32),
#  array([ 5.30095 , -5.581394], dtype=float32),
#  array([ 5.4323153, -5.7247443], dtype=float32),
#  array([ 3.6564655, -3.7831986], dtype=float32),
#  array([ 5.60432  , -5.9125724], dtype=float32),
#  array([ 5.345419, -5.629894], dtype=float32),
#  array([ 4.7642655, -4.9954786], dtype=float32),
#  array([ 6.0751457, -6.4265437], dtype=float32),
#  array([ 6.537364 , -6.9312267], dtype=float32),
#  array([ 5.318043, -5.599992], dtype=float32),
#  array([ 7.2256994, -7.6827765], dtype=float32),
#  array([ 7.024094 , -7.4625874], dtype=float32),
#  array([ 6.469546, -6.857267], dtype=float32),
#  array([ 5.0022316, -5.255246 ], dtype=float32),
#  array([ 6.16756  , -6.5274158], dtype=float32),
#  array([ 2.961778 , -3.0176847], dtype=float32),
#  array([-2.5106397,  3.1561725], dtype=float32),
#  array([ 7.6522384, -8.148454 ], dtype=float32),
#  array([-1.3195729,  1.812202 ], dtype=float32),
#  array([ 4.807811 , -5.0430756], dtype=float32),
#  array([ 0.49022225, -0.229166  ], dtype=float32),
#  array([ 8.057819, -8.591153], dtype=float32),
#  array([-2.276075,  2.88455 ], dtype=float32),
#  array([ 5.0574546, -5.315522 ], dtype=float32),
#  array([ 7.061103, -7.502974], dtype=float32),
#  array([ 4.64085 , -4.860805], dtype=float32),
#  array([-2.005932 ,  2.5723085], dtype=float32),
#  array([ 5.9113803, -6.2478223], dtype=float32),
#  array([ 4.511673 , -4.7200246], dtype=float32),
#  array([ 6.3277707, -6.702403 ], dtype=float32),
#  array([ 5.637042, -5.948284], dtype=float32),
#  array([ 6.6789484, -7.0857725], dtype=float32),
#  array([ 2.8023376, -2.840853 ], dtype=float32),
#  array([ 4.166202, -4.34229 ], dtype=float32),
#  array([ 5.073366 , -5.3328915], dtype=float32),
#  array([ 6.2166595, -6.5810795], dtype=float32),
#  array([ 5.1625547, -5.430291 ], dtype=float32),
#  array([ 4.952666, -5.201157], dtype=float32),
#  array([ 6.7527227, -7.166364 ], dtype=float32),
#  array([ 3.862189, -4.008568], dtype=float32),
#  array([ 3.123134 , -3.1951811], dtype=float32),
#  array([ 7.4872346, -7.96825  ], dtype=float32),
#  array([ 3.9892795, -4.1482   ], dtype=float32),
#  array([ 6.6154704, -7.0165267], dtype=float32),
#  array([ 4.955793 , -5.2045836], dtype=float32),
#  array([ 5.317591 , -5.5995326], dtype=float32),
#  array([ 1.231602 , -1.0635741], dtype=float32),
#  array([ 4.3784323, -4.5745187], dtype=float32),
#  array([ 5.3511953, -5.6362443], dtype=float32),
#  array([ 5.759134, -6.081601], dtype=float32),
#  array([ 4.060671 , -4.2264376], dtype=float32),
#  array([ 5.0263243, -5.281582 ], dtype=float32),
#  array([ 5.495858 , -5.7941523], dtype=float32),
#  array([ 4.873297, -5.114541], dtype=float32),
#  array([ 5.6471467, -5.959334 ], dtype=float32),
#  array([ 6.8821177, -7.30762  ], dtype=float32),
#  array([ 5.241284, -5.516224], dtype=float32),
#  array([ 6.9437523, -7.3748755], dtype=float32),
#  array([ 6.557842, -6.953559], dtype=float32),
#  array([ 8.640779, -9.227933], dtype=float32),
#  array([ 5.3923864, -5.681191 ], dtype=float32),
#  array([ 5.292031 , -5.5716267], dtype=float32),
#  array([ 4.388074, -4.585277], dtype=float32),
#  array([ 5.147895 , -5.4143014], dtype=float32),
#  array([ 3.3585417, -3.4547503], dtype=float32),
#  array([ 4.6452236, -4.865594 ], dtype=float32),
#  array([-1.8612621,  2.4048584], dtype=float32),
#  array([ 5.265982 , -5.5432014], dtype=float32),
#  array([-2.4927719,  3.1353722], dtype=float32),
#  array([ 5.0838985, -5.344423 ], dtype=float32),
#  array([-2.2661607,  2.8730183], dtype=float32),
#  array([ 5.326831 , -5.6096463], dtype=float32),
#  array([-2.3120608,  2.9260602], dtype=float32),
#  array([ 7.142143 , -7.5914993], dtype=float32),
#  array([-2.22908  ,  2.8304255], dtype=float32),
#  array([ 4.2116814, -4.3919463], dtype=float32),
#  array([ 5.5448217, -5.847593 ], dtype=float32),
#  array([ 4.61065, -4.82787], dtype=float32),
#  ...]

# %%
import scipy as sc
from sklearn.metrics import roc_auc_score, roc_curve

softmax = sc.special.softmax(predictions, axis=1)

print(softmax[:,1])

# [x, y]
# x: prob for 0
# y: prob for 1
# 1 means labelled as speech, 0 means labelled as article

# labels are given in data_test_labels, and the probabilities for being labelled as speech (1) are given in softmax[:,1]

y_prob = softmax[:,1]

y_pred = np.zeros(y_prob.shape)
y_pred[y_prob > 0.5] = 1

print(np.sum(y_pred))
print(np.sum(data_val_labels))

#auc = roc_auc_score(data_test_labels, y_prob)
auc = roc_auc_score(data_val_labels, y_prob)

fpr, tpr, _ = roc_curve(data_val_labels, y_prob)

plt.figure(figsize=(10,10))
plt.plot(fpr,tpr,label=f"AUC = {auc:.3f}")
# Out:
# [9.6871554e-07 1.9370797e-05 3.3084177e-08 ... 7.1045346e-05 1.1927491e-05
#  9.0090623e-07]
# 898.0
# 959.0
